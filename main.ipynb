# %% [markdown]
# Visualizations

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv("D:\\leona\\University\\Third Year\\Thesis\\Code\\thesis\\data\\comparison_size_data.csv")

# %%
sns.pointplot(df[df.type != "standard"], x="size", y="iterations", hue="type")
# Out:
# <Axes: xlabel='size', ylabel='iterations'>
